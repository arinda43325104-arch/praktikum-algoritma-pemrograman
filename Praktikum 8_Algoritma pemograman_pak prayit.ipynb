# %% [markdown]
# <a href="https://colab.research.google.com/github/arinda43325104-arch/praktikum-algoritma-pemrograman/blob/main/Praktikum%208_Algoritma%20pemograman_pak%20prayit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 1 : Fungsi Dasar dengan def

# %%
def sapa () :
  print("Halo, selamat datang di Politeknik Negeri Semarang!")
sapa ()
# Out:
# Halo, selamat datang di Politeknik Negeri Semarang!

# %% [markdown]
# Praktikum 2 : Fungsi dengan Parameter dan Return

# %%
def tambah (a, b) :
  return a + b

hasil = tambah (7, 3)
print("Hasil penjumlahan:", hasil)
# Out:
# Hasil penjumlahan: 10

# %% [markdown]
# Praktikum 3 : Fungsi dengan Default Argument

# %%
def sapa(nama="Mahasiswa") :
  print(f"Halo, {nama}!")

sapa() # tanpa argumen
sapa("Andi") # dengan argumen
# Out:
# Halo, Mahasiswa!
# Halo, Andi!

# %% [markdown]
# Praktikum 4 : Fungsi dengan *args dan **kwargs

# %%
def jumlahkan(*args):
  return sum(args)

def biodata(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}: {value}")

print("Total:", jumlahkan(1, 2, 3, 4, 5))
biodata(Nama="Budi", Umur=20, Prodi="TRK")
# Out:
# Total: 15
# Nama: Budi
# Umur: 20
# Prodi: TRK

# %% [markdown]
# Praktikum 5 : Scope Variabel

# %%
x = 10

def ubah():
 x = 5
 print("Nilai lokal:", x)

ubah()
print("Nilai global:", x)
# Out:
# Nilai lokal: 5
# Nilai global: 10

# %% [markdown]
# Praktikum 6 : Fungsi Lambda

# %%
kali = lambda x, y: x * y
print("Hasil perkalian:", kali(4, 5))
# Out:
# Hasil perkalian: 20

# %% [markdown]
# Praktikum 7 : Fungsi Decorator

# %%
def decorator_sapa(fungsi):
  def wrapper():
    print("Sebelum fungsi dijalankan...")
    fungsi()
    print("Setelah fungsi dijalankan...")
  return wrapper

@decorator_sapa
def sapa():
  print("Halo, selamat datang!")

sapa()
# Out:
# Sebelum fungsi dijalankan...
# Halo, selamat datang!
# Setelah fungsi dijalankan...

# %% [markdown]
# Praktikum 8 : Studi Kasus_Menghitung Rata-rata Nilai Mahasiswa

# %%
def hitung_rata(data):
  return sum(data) / len(data)

nilai = [80, 90, 85]
rata = hitung_rata(nilai)

print("Rata-rata nilai:", rata)
# Out:
# Rata-rata nilai: 85.0

# %% [markdown]
# Penugasan 1 : Fungsi Sederhana

# %%
def sapa () :
  print("Halo, nama saya Arinda, saya dari TRK")
sapa ()
# Out:
# Halo, nama saya Arinda, saya dari TRK

# %% [markdown]
# Penugasan 2 : Fungsi dengan Parameter dan Return

# %%
def luas_persegi (panjang, lebar) :
  return panjang * lebar

hasil1 = (7 * 3)
hasil2 = ( 5 * 9)
hasil3 = (6 * 5)
print("Hasil luas persegi panjang:", hasil1)
print("Hasil luas persegi panjang:", hasil2)
print("Hasil luas persegi panjang:", hasil3)
# Out:
# Hasil luas persegi panjang: 21
# Hasil luas persegi panjang: 45
# Hasil luas persegi panjang: 30

# %% [markdown]
# Penugasan 3 : Fungsi dengan Default Argument

# %%
def salam(waktu="pagi") :
  print(f"Selamat {waktu}!")

salam("Pagi, Killian") # tanpa argumen
# Out:
# Selamat Pagi, Killian!

# %% [markdown]
# Penugasan 4 : Fungsi dengan Args

# %%
def jumlahkan(*args):
  return sum(args)

print("Total uji 1:", jumlahkan(3, 5, 7))
print("Total uji 2:", jumlahkan(3, 5, 7, 9, 11))
print("Total uji 3:", jumlahkan(3, 5, 7, 9, 11, 13, 15))
# Out:
# Total uji 1: 15
# Total uji 2: 35
# Total uji 3: 63

# %% [markdown]
# Penugasan 5 : Fungsi dengan Kwargs

# %%
def biodata(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}: {value}")

biodata(Nama="Buku", Harga=15000, Stok=30)
# Out:
# Nama: Buku
# Harga: 15000
# Stok: 30

# %% [markdown]
# Penugasan 6 : Scope Variabel

# %%
x = 100

def ubah():
 x = 50
 print("Nilai x didalam fungsi:", x)

ubah()
print("Nilai x diluar fungsi:", x)
# Out:
# Nilai x didalam fungsi: 50
# Nilai x diluar fungsi: 100

# %% [markdown]
# Penugasan 7 : Fungsi Lambda

# %%
kuadrat = lambda x : x ** 2
print("Hasil kuadrat:", kuadrat(3))
Keliling_lingkaran = lambda r : 2 * 3.14 * r
print("Keliling lingkaran:", Keliling_lingkaran(7))
# Out:
# Hasil kuadrat: 9
# Keliling lingkaran: 43.96

# %% [markdown]
# Penugasan 8 : Fungsi Decorator

# %%
def decorator_sapa(fungsi):
  def wrapper():
    print("Memulai fungsi...")
    fungsi()
    print("Fungsi selesai dijalankan...")
  return wrapper

@decorator_sapa
def sapa():
  print("Halo, selamat pagi semua!")

sapa()
# Out:
# Memulai fungsi...
# Halo, selamat pagi semua!
# Fungsi selesai dijalankan...

# %% [markdown]
# Penugasan 9 : Studi Kasus Nyata - Program Nilai

# %%
def input_nilai():
    return [80, 90, 85]

def hitung_rata(data):
    return sum(data) / len(data)

def status_kelulusan(rata):
    if rata >= 60:
        return "Lulus"
    else:
        return "Tidak Lulus"

nilai_akhir = lambda tugas, ujian: (0.4 * tugas) + (0.6 * ujian)

print("Nilai:", nilai)
print("Rata-rata:", rata)
print("Status:", status_kelulusan(rata))

tugas = 85
ujian = 90
print("Nilai akhir:", nilai_akhir(tugas, ujian))
# Out:
# Nilai: [80, 90, 85]
# Rata-rata: 85.0
# Status: Lulus
# Nilai akhir: 88.0
